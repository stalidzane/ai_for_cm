# %% [markdown]
# # 📓 Jupyter & Data Science Environment Test
#
# This notebook verifies that the **Jupyter** environment is correctly configured and has access to the libraries installed via **Mamba**.

# %% [markdown]
# ### 1. Kernel and Import Verification

# %%
import sys
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sklearn
import duckdb

print(f"Python version: {sys.version}")
print(f"NumPy version: {np.__version__}")
print(f"Pandas version: {pd.__version__}")
print(f"Scikit-learn version: {sklearn.__version__}")
print(f"DuckDB version: {duckdb.__version__}")
# Out:
# Python version: 3.14.3 | packaged by conda-forge | (main, Feb  9 2026, 22:09:14) [Clang 20.1.8 ]
# NumPy version: 2.4.3
# Pandas version: 3.0.1
# Scikit-learn version: 1.8.0
# DuckDB version: 1.5.0

# %% [markdown]
# ### 2. Pandas and Data Visualization Test

# %%
data = {
    'Month': ['Jan', 'Feb', 'Mar', 'Apr', 'May'],
    'Sales': [100, 150, 120, 200, 180]
}
df = pd.DataFrame(data)
df
# Out:
#   Month  Sales
# 0   Jan    100
# 1   Feb    150
# 2   Mar    120
# 3   Apr    200
# 4   May    180

# %% [markdown]
# ### 3. Matplotlib Test (Inline Plotting)

# %%
# %matplotlib inline
plt.figure(figsize=(10, 5))
plt.bar(df['Month'], df['Sales'], color='skyblue')
plt.title('Sales Performance')
plt.xlabel('Month')
plt.ylabel('Units Sold')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %% [markdown]
# ### 4. DuckDB Test

# %%
import duckdb

con = duckdb.connect()
# Querying the CSV directly and converting to DataFrame
df_duck = con.execute("SELECT * FROM read_csv_auto('test_data.csv')").df()
print("✅ DuckDB: CSV loaded and queried successfully.")
df_duck.head()
# Out:
# ✅ DuckDB: CSV loaded and queried successfully.
#    id    name  value
# 0   1  Item A  10.50
# 1   2  Item B  23.00
# 2   3  Item C  15.75
# 3   4  Item D  42.00
# 4   5  Item E  12.50
